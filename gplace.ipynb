# %%
import os
import requests
import utils
from langchain_core.tools import tool

utils.load_env()


def find_place_from_text(input_text, location=None, radius=2000):
    "Finds a place based on text input and location bias."
    # Retrieve the API key from environment variables
    api_key = os.getenv('GPLACES_API_KEY')

    if not api_key:
        raise ValueError("API key not found. Please set the GOOGLE_MAPS_API_KEY environment variable.")

    # Define the endpoint URL
    url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"

    # Define the parameters for the request
    params = {
        'fields': 'formatted_address,name,rating,opening_hours,geometry',
        'input': input_text,
        'inputtype': 'textquery',
        'key': api_key
    }
    
    params['locationbias'] = f'circle:{radius}@{location}' if location is not None and radius is not None else None

    # Make the request to the Google Maps API
    response = requests.get(url, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        return response.json()  # Return the JSON response
    else:
        response.raise_for_status()  # Raise an exception for HTTP errors


def find_location(input_text:str, location:str=None, radius=2000):
    """Returns the latitude and longitude of a location based on text input."""
    # Call the find_place_from_text function to get the location data
    data = find_place_from_text(input_text, location, radius)

    # Extract the latitude and longitude from the response
    candidates = data.get('candidates', [])
    if len(candidates)==0:
        raise ValueError("No location found.")

    # Assuming we're taking the first candidate
    geometry = candidates[0].get('geometry', {})
    location = geometry.get('location', {})

    latitude = location.get('lat')
    longitude = location.get('lng')

    if latitude is None or longitude is None:
        raise ValueError("Latitude or Longitude not found in the response.")

    # Return the latitude and longitude as a formatted string
    return f"{latitude},{longitude}"


def nearby_search_old(keyword:str, location:str, radius=2000, place_type=None):
    """Searches for nearby places based on a keyword and location."""
    # Retrieve the API key from environment variables
    api_key = os.getenv('GPLACES_API_KEY')

    if not api_key:
        raise ValueError("API key not found. Please set the GOOGLE_MAPS_API_KEY environment variable.")

    # Define the endpoint URL
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # Set up the parameters for the request
    params = {
        'keyword': keyword,
        'location': location,
        'radius': radius,
        'type': place_type,
        'key': api_key,
    }

    # Send the GET request to the Google Maps API
    response = requests.get(url, params=params)

    # Check if the request was successful
    if response.status_code != 200:
        raise Exception(f"Error with request: {response.status_code}, {response.text}")

    # Parse the JSON response
    data = response.json()

    # Return the response data
    return data['results']


def nearby_search(keyword:str, location:str, radius=2000, place_type=None):
    # Retrieve the API key from environment variables
    api_key = os.getenv('GPLACES_API_KEY')

    if not api_key:
        raise ValueError("API key not found. Please set the GOOGLE_MAPS_API_KEY environment variable.")

    # Define the endpoint URL
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # Set up the parameters for the request
    params = {
        'keyword': keyword,
        'location': location,
        'radius': radius,
        'type': place_type,
        'key': api_key,
        "rankPreference": "DISTANCE"
    }

    # Send the GET request to the Google Maps API
    response = requests.get(url, params=params)

    # Check if the request was successful
    if response.status_code != 200:
        raise Exception(f"Error with request: {response.status_code}, {response.text}")

    # Parse the JSON response
    data = response.json()
    results = data['results']

    # search into next page
    while data.get('next_page_token', False):
        params = {'next_page_token': data['next_page_token']}
        response = requests.get(url, params=params)
        
        if response.status_code != 200:
            raise Exception(f"Error with request: {response.status_code}, {response.text}")
        
        data = response.json()
        
        results.append(data['results'])
        

    # Return the response data
    return results


def nearby_dense_community(location:str, radius:int=1000):
    # Retrieve the API key from environment variables
    api_key = os.getenv('GPLACES_API_KEY')

    if not api_key:
        raise ValueError("API key not found. Please set the GOOGLE_MAPS_API_KEY environment variable.")

    # Define the endpoint URL
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # Set up the parameters for the request
    params = {
        "includedTypes": ["lodging", "mall", "school"],
        'location': location,
        'radius': radius,
        'key': api_key,
        "rankPreference": "DISTANCE"
    }

    # Send the GET request to the Google Maps API
    response = requests.get(url, params=params)

    # Check if the request was successful
    if response.status_code != 200:
        raise Exception(f"Error with request: {response.status_code}, {response.text}")

    # Parse the JSON response
    data = response.json()
    results = data['results']

    # Return the response data
    return results

# %%
find_place_from_text("mbk center")
# Out:
# {'candidates': [{'formatted_address': '444 ถ. พญาไท แขวงวังใหม่ เขตปทุมวัน กรุงเทพมหานคร 10330 ไทย',
#    'geometry': {'location': {'lat': 13.744677, 'lng': 100.5295593},
#     'viewport': {'northeast': {'lat': 13.74598387989272,
#       'lng': 100.5309299798927},
#      'southwest': {'lat': 13.74328422010728, 'lng': 100.5282303201073}}},
#    'name': 'เอ็ม บี เค เซ็นเตอร์',
#    'opening_hours': {'open_now': True},
#    'rating': 4.3}],
#  'status': 'OK'}

# %%
location_coords = find_location('โรงเรียนบดินทรเดชา (สิงห์ สิงหเสนี) ๒​')
nearby_dense_community(location_coords)
# Out:
# [{'geometry': {'location': {'lat': 13.7563309, 'lng': 100.5017651},
#    'viewport': {'northeast': {'lat': 13.9551109646008,
#      'lng': 100.9384080394661},
#     'southwest': {'lat': 13.4940880622837, 'lng': 100.3278135588086}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Bangkok',
#   'photos': [{'height': 934,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107853816016331257868">Harshvardhan Mali</a>'],
#     'photo_reference': 'AXCi2Q4TEeoXw9DVO1GhkDiKWgF6yeO2KzX_yeAj8yHsBo9oSxX3jB392RcJvV5H6HoDlH7BstIBpJLTmfL7lO2hfwOZfmDFGN-PBTEsDaOOKkOeaR5rr5GEMqdAH2KdnPEaQIiBgaxsMQXTW4qkrhZE9phoPb4XqbLRmCrQlXDQ8ZMdlY7H',
#     'width': 756}],
#   'place_id': 'ChIJ82ENKDJgHTERIEjiXbIAAQE',
#   'reference': 'ChIJ82ENKDJgHTERIEjiXbIAAQE',
#   'scope': 'GOOGLE',
#   'types': ['locality', 'political'],
#   'vicinity': 'Bangkok'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 13.809367, 'lng': 100.65344},
#    'viewport': {'northeast': {'lat': 13.8106824802915,
#      'lng': 100.6548797302915},
#     'southwest': {'lat': 13.8079845197085, 'lng': 100.6521817697085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Golden Apartment',
#   'place_id': 'ChIJq6qqqgZjHTERH8-k0V9HEvU',
#   'plus_code': {'compound_code': 'RM53+P9 Bangkok, Thailand',
#    'global_code': '7P52RM53+P9'},
#   'rating': 5,
#   'reference': 'ChIJq6qqqgZjHTERH8-k0V9HEvU',
#   'scope': 'GOOGLE',
#   'types': ['point_of_interest', 'establishment'],
#   'user_ratings_total': 1,
#   'vicinity': 'Thailand'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 13.819292, 'lng': 100.6535616},
#    'viewport': {'northeast': {'lat': 13.8205699302915,
#      'lng': 100.6549267802915},
#     'southwest': {'lat': 13.8178719697085, 'lng': 100.6522288197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Sukij Film Auto Accessories',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102601096029727548979">พรทิพย์ฟิล์ม ประดับยนต์</a>'],
#     'photo_reference': 'AXCi2Q50SnLd4QLfywOorYvoV5DrRSETzqipRiEIGxqHV6Ks3WTs_MI4O41QB2VpKZ-Uv9KMkrF7Erufz-Rc9A0_F_gbY3X83Fvshuah_tbsBRQXiYdH-rlFNfZWR3xMdunRZ9IlBw7Ub_xH-zJTu7lXbpauD6lO-FTT3CIjgeO08vNelZ0E',
#     'width': 4032}],
#   'place_id': 'ChIJY60Gi1xiHTERhW8mj5WcimE',
#   'plus_code': {'compound_code': 'RM93+PC Bangkok, Thailand',
#    'global_code': '7P52RM93+PC'},
#   'rating': 4.5,
#   'reference': 'ChIJY60Gi1xiHTERhW8mj5WcimE',
#   'scope': 'GOOGLE',
#   'types': ['point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 10,
#   'vicinity': '32/8 Thanon Ratchada-Ram Intra, Khwaeng Nuanchan, Khet Bueng Kum'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 13.8210585, 'lng': 100.6495779},
#    'viewport': {'northeast': {'lat': 13.8224923302915,
#      'lng': 100.6509220802915},
#     'southwest': {'lat': 13.8197943697085, 'lng': 100.6482241197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Thanee Condo Town',
#   'place_id': 'ChIJNZ9KJ_ZiHTERX6DiEQW1_Hk',
#   'rating': 4.8,
#   'reference': 'ChIJNZ9KJ_ZiHTERX6DiEQW1_Hk',
#   'scope': 'GOOGLE',
#   'types': ['point_of_interest', 'establishment'],
#   'user_ratings_total': 5,
#   'vicinity': 'RJCX+CRG, Bangkok'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 13.8173301, 'lng': 100.65913},
#    'viewport': {'northeast': {'lat': 13.8186787302915,
#      'lng': 100.6604079802915},
#     'southwest': {'lat': 13.8159807697085, 'lng': 100.6577100197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Poteam Builder Co., Ltd.',
#   'photos': [{'height': 1734,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105729397699924286884">Than Soe</a>'],
#     'photo_reference': 'AXCi2Q4doBu46bFnyaC6dWsIPKYM8QEpCU3cFguk8y5WALZmmujCYuKc3hlz6wz6aXWYB7LJbk9bvp6sd-w2M5l6WA7nk4LuPTzzYZp8yNzO3xtsjZrH4Ua_zUMgpUKIFafhMfMQjR2Xitn0iwd7mC9Z6XPlW7MSH1HFgNSOQJ95tkeCVC82',
#     'width': 1734}],
#   'place_id': 'ChIJjW2gwj6Z4jARRvHMIqG5dbk',
#   'plus_code': {'compound_code': 'RM85+WM Bangkok, Thailand',
#    'global_code': '7P52RM85+WM'},
#   'rating': 3.9,
#   'reference': 'ChIJjW2gwj6Z4jARRvHMIqG5dbk',
#   'scope': 'GOOGLE',
#   'types': ['general_contractor', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 21,
#   'vicinity': '46, 257 Soi Nawamin 74 Yeak 3-1, Khwaeng Khlong Kum, Khet Bueng Kum'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 13.8111225, 'lng': 100.6539164},
#    'viewport': {'northeast': {'lat': 13.8124504302915,
#      'lng': 100.6552577802915},
#     'southwest': {'lat': 13.8097524697085, 'lng': 100.6525598197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'ศูนย์ขาย Ubiquiti Networks โดย บจก.ราสเบอรี่',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3999,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109283225708495485874">ศูนย์ขาย Ubiquiti Networks โดย บจก.ราสเบอรี่</a>'],
#     'photo_reference': 'AXCi2Q754Ia3JB16YIRSD_bI9HKQl66L5NE8CzP7I0LPqlLCfBOL6UswHjOazSmKtEDYe7-yxqaeEuEFNgLxqPG_34locmQSZfgbywKK5kaUg0CtjYEWUdnLVx6fTxMWeyWLRq77xR0k1u0jlflZPSPVfDUgpmjM8LlArisbXxiuAXpOy_XB',
#     'width': 3000}],
#   'place_id': 'ChIJNfe3yW5iHTERRHfvqX9W-9o',
#   'plus_code': {'compound_code': 'RM63+CH Bangkok, Thailand',
#    'global_code': '7P52RM63+CH'},
#   'rating': 5,
#   'reference': 'ChIJNfe3yW5iHTERRHfvqX9W-9o',
#   'scope': 'GOOGLE',
#   'types': ['electronics_store',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 4,
#   'vicinity': '318, 111 Soi Nawamin 70, Khwaeng Khlong Kum, Khet Bueng Kum'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 13.8127991, 'lng': 100.6514681},
#    'viewport': {'northeast': {'lat': 13.8141354802915,
#      'lng': 100.6528465802915},
#     'southwest': {'lat': 13.8114375197085, 'lng': 100.6501486197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'ห้างหุ้นส่วนจำกัด 101 สเตชั่นเนอรี่',
#   'opening_hours': {'open_now': True},
#   'place_id': 'ChIJlXYawmpiHTER2PonVZjksk4',
#   'reference': 'ChIJlXYawmpiHTER2PonVZjksk4',
#   'scope': 'GOOGLE',
#   'types': ['point_of_interest', 'store', 'establishment'],
#   'vicinity': 'หมู่ที่ 5, 645/111 ซอยโพธิ์แก้ว ถนนนวมินทร์, Khwaeng Khlong Kum, Khet Bueng Kum'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 13.8180099, 'lng': 100.6547856},
#    'viewport': {'northeast': {'lat': 13.8194425802915,
#      'lng': 100.6561749802915},
#     'southwest': {'lat': 13.8167446197085, 'lng': 100.6534770197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet',
#   'name': 'Global Art & Creative ศูนย์นวมินทร์',
#   'opening_hours': {'open_now': False},
#   'place_id': 'ChIJRds6p1diHTERaa59iWjqjQ8',
#   'plus_code': {'compound_code': 'RM93+6W Bangkok, Thailand',
#    'global_code': '7P52RM93+6W'},
#   'reference': 'ChIJRds6p1diHTERaa59iWjqjQ8',
#   'scope': 'GOOGLE',
#   'types': ['school', 'point_of_interest', 'establishment'],
#   'vicinity': '700/41 MaxValu นวมินทร์ (ตึกด้านนอก ชั้น 2) ถนนนวมินทร์ แขวงบึงกุ่ม เขตบึงกุ่ม กรุงเทพมหานคร 10240'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 13.8152594, 'lng': 100.656179},
#    'viewport': {'northeast': {'lat': 13.8166640302915,
#      'lng': 100.6575269802915},
#     'southwest': {'lat': 13.8139660697085, 'lng': 100.6548290197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'สยามออโต้บอดี้ ศูนย์ซ่อมสี',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 791,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105849080658451569224">สยามออโต้บอดี้ ศูนย์ซ่อมสี</a>'],
#     'photo_reference': 'AXCi2Q4FpeZJZODE7shZvO-dxDcUigizsxpu2_VdoBa9ugqL7v1S6IDxr7BN4aGbtBy6E1k8X5qp7-amTn1_qwY68xcJ_Xmz3GOUAulGFl09u2z5-J6pg8w4R4Zu9JKckwwZc8VmOPkz64LTp80YfhUIo3wb9x8y77MAEBR5a6Qw2uc7wCry',
#     'width': 1470}],
#   'place_id': 'ChIJyRASmJqd4jARMCFD1X1ILAU',
#   'plus_code': {'compound_code': 'RM84+4F Bangkok, Thailand',
#    'global_code': '7P52RM84+4F'},
#   'rating': 4.1,
#   'reference': 'ChIJyRASmJqd4jARMCFD1X1ILAU',
#   'scope': 'GOOGLE',
#   'types': ['car_repair', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 84,
#   'vicinity': '109, 7 Soi Nawamin 74 Yeak 9, Khwaeng Khlong Kum, Khet Bueng Kum'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 13.818035, 'lng': 100.654871},
#    'viewport': {'northeast': {'lat': 13.8194414802915,
#      'lng': 100.6562477302915},
#     'southwest': {'lat': 13.8167435197085, 'lng': 100.6535497697085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'ก๋วยเตี๋ยวเรือ อ.ต.ก.',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115318087310414787082">Busaba Wanchana</a>'],
#     'photo_reference': 'AXCi2Q5V03mMwpCCDjAV8pfRbNs5V4qZ_MymD-GPOjQg2IFCsRyMI6GP90jjTX8Mzxp3XfDCQZjJyLnEctm2OLzxPejrcL9H9uU-IIF0wYLc6MwVfKjc4iMsYwdGRqwneLeW6a11H71dGPq9yujxVknIVsL3uXnL9t8kOmAyMmcJ78UY5IUC',
#     'width': 3024}],
#   'place_id': 'ChIJAVspoFdiHTER9sA8e95Me1k',
#   'plus_code': {'compound_code': 'RM93+6W Bangkok, Thailand',
#    'global_code': '7P52RM93+6W'},
#   'rating': 3.8,
#   'reference': 'ChIJAVspoFdiHTER9sA8e95Me1k',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 28,
#   'vicinity': '700/40 ศูนย์การค้าอิออน ถ.นวมินทร์ แขวงคลองกุ่ม, Khet Bueng Kum'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 13.8180244, 'lng': 100.6580208},
#    'viewport': {'northeast': {'lat': 13.8194756802915,
#      'lng': 100.6593455302915},
#     'southwest': {'lat': 13.8167777197085, 'lng': 100.6566475697085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Prapas Safe 1996 Co., Ltd.',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3968,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101677816535463102049">สุเทพ คลาดโรค</a>'],
#     'photo_reference': 'AXCi2Q6H7_Ki6-0nL3LFCYJPNj5LXEGGrlnFWDYqxU1lnrsYR419_vy-ACzDSgwCKBlsmuFkjHOnH1_Y7HyMwS-U8goKgTg3NxQ8JlWydVeT-Yn18VQgq5yyglrDNW1cNABYubAKxIfhvYUKnewHxzsSLzDgG6uJyy9XpUPxWy4FdFYt1bm7',
#     'width': 2976}],
#   'place_id': 'ChIJsesMYkdiHTER68a-Ci2pBR0',
#   'plus_code': {'compound_code': 'RM95+66 Bangkok, Thailand',
#    'global_code': '7P52RM95+66'},
#   'rating': 4.2,
#   'reference': 'ChIJsesMYkdiHTER68a-Ci2pBR0',
#   'scope': 'GOOGLE',
#   'types': ['point_of_interest', 'establishment'],
#   'user_ratings_total': 21,
#   'vicinity': '46/94 Soi Nawamin 74 Yeak 1, Khwaeng Khlong Kum, Khet Bueng Kum'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 13.8164901, 'lng': 100.6524682},
#    'viewport': {'northeast': {'lat': 13.8177859302915,
#      'lng': 100.6538348802915},
#     'southwest': {'lat': 13.8150879697085, 'lng': 100.6511369197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'RCM88',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4608,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101934906852399498311">บุญเกษม ยิ้มฉาย</a>'],
#     'photo_reference': 'AXCi2Q7lU24a3nxI_pGhal2zT99SeiM2wCPlroEoMOyDzsmZzNVyhBKaFtTBdaJynN-7cEE9sDndXEN48qEr99eOpu-SVAAgh9kI6y8qIK4iuXChY7WKCZcNtrTcZMQSHv5QH5Lj91boUzlffztGi_ZKUXsPiweDmdOH_-FRYSv4olzmDPyk',
#     'width': 3456}],
#   'place_id': 'ChIJIbnb81liHTERmPvWtMIEv2g',
#   'plus_code': {'compound_code': 'RM82+HX Bangkok, Thailand',
#    'global_code': '7P52RM82+HX'},
#   'rating': 4.3,
#   'reference': 'ChIJIbnb81liHTERmPvWtMIEv2g',
#   'scope': 'GOOGLE',
#   'types': ['general_contractor',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 85,
#   'vicinity': '111, 1 Soi Nawamin 127, Khwaeng Nuanchan, Khet Bueng Kum'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 13.8195678, 'lng': 100.6552623},
#    'viewport': {'northeast': {'lat': 13.8208810302915,
#      'lng': 100.6566184302915},
#     'southwest': {'lat': 13.8181830697085, 'lng': 100.6539204697085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'ปราสาททองโอสถ บจก.',
#   'opening_hours': {'open_now': True},
#   'place_id': 'ChIJKTptcENiHTERinsv23H00AA',
#   'plus_code': {'compound_code': 'RM94+R4 Bangkok, Thailand',
#    'global_code': '7P52RM94+R4'},
#   'rating': 5,
#   'reference': 'ChIJKTptcENiHTERinsv23H00AA',
#   'scope': 'GOOGLE',
#   'types': ['point_of_interest', 'health', 'establishment'],
#   'user_ratings_total': 3,
#   'vicinity': '24, 66 Thanon Ratchada-Ram Intra, Khwaeng Nuanchan, Khet Bueng Kum'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 13.8180748, 'lng': 100.6542916},
#    'viewport': {'northeast': {'lat': 13.8193758302915,
#      'lng': 100.6556182302915},
#     'southwest': {'lat': 13.8166778697085, 'lng': 100.6529202697085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Ban Satliang Veterinary Hospital',
#   'place_id': 'ChIJB3OYgFdiHTERlV_c8wubRnk',
#   'plus_code': {'compound_code': 'RM93+6P Bangkok, Thailand',
#    'global_code': '7P52RM93+6P'},
#   'rating': 2,
#   'reference': 'ChIJB3OYgFdiHTERlV_c8wubRnk',
#   'scope': 'GOOGLE',
#   'types': ['veterinary_care', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1,
#   'vicinity': '265 Soi Nawamin 74, Khwaeng Khlong Kum, Khet Bueng Kum'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 13.8123742, 'lng': 100.649877},
#    'viewport': {'northeast': {'lat': 13.8137217302915,
#      'lng': 100.6512233802915},
#     'southwest': {'lat': 13.8110237697085, 'lng': 100.6485254197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': '68 Studio',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2976,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101493350055125837041">HubP Campany</a>'],
#     'photo_reference': 'AXCi2Q6Pi_MQNy66pBPZtwiIrs9j84EIyDQdPnRZL4eWE1OeIjEKQAJ7-fYVaxvS7TH4sK2B5A0EZgNxszIAYKCjOCOlnPv2GKqAZ_OcL85BcYcmDOixv4mx1a2pCFloB-2Eo4GXT5T9FSkkcPStFLx_88BhBC9RSj4bqsh3MehlPO1RBNBq',
#     'width': 3968}],
#   'place_id': 'ChIJ7VOwBltiHTERiRgUb7GHY-U',
#   'plus_code': {'compound_code': 'RJ6X+WX Bangkok, Thailand',
#    'global_code': '7P52RJ6X+WX'},
#   'rating': 4.5,
#   'reference': 'ChIJ7VOwBltiHTERiRgUb7GHY-U',
#   'scope': 'GOOGLE',
#   'types': ['point_of_interest', 'establishment'],
#   'user_ratings_total': 39,
#   'vicinity': '152 113, 49/27 ถนน นวมินทร์, แขวงคลองกุ่ม, เขตบึงกุ่ม'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 13.810815, 'lng': 100.654034},
#    'viewport': {'northeast': {'lat': 13.8121225802915,
#      'lng': 100.6553674802915},
#     'southwest': {'lat': 13.8094246197085, 'lng': 100.6526695197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#   'name': 'P18 Coffee & MOTO OUTLET',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 480,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107143217356340278257">P18 Coffee &amp; MOTO OUTLET</a>'],
#     'photo_reference': 'AXCi2Q7YXmRgykShnZqMQHISjJv09xk5yz2GTpy-HXfp6H5IUuv4oma0NJZjKGOLPr1IZj_9fNZNu2r0xBbsOdHFSA2bMWYSHycfl27bhPkHEoLkZuTKH_5DR3vP-ZnbNFgkxR6FilaLgE5qd2rt3I1--pxC-98779s4OQY8mAhs-FC5XFrw',
#     'width': 721}],
#   'place_id': 'ChIJOV_PclBiHTERwtM0FGDtxFc',
#   'plus_code': {'compound_code': 'RM63+8J Bangkok, Thailand',
#    'global_code': '7P52RM63+8J'},
#   'rating': 4,
#   'reference': 'ChIJOV_PclBiHTERwtM0FGDtxFc',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'point_of_interest', 'store', 'food', 'establishment'],
#   'user_ratings_total': 3,
#   'vicinity': '318/107 ซ.นวมินทร์70 ถ.นวมินทร์ แขวงคลองกุ่ม, Khet Bueng Kum'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 13.8113796, 'lng': 100.6555015},
#    'viewport': {'northeast': {'lat': 13.8126681802915,
#      'lng': 100.6568264802915},
#     'southwest': {'lat': 13.8099702197085, 'lng': 100.6541285197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Cinnamic Since 1972 co., Ltd.',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1477,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101571175199361500506">ESTELL THAILAND</a>'],
#     'photo_reference': 'AXCi2Q55Wk12Wb_NDJ_f_m4RqfPjUyqHBBnFFLL2T4p8ftfubYrYV32bpgYGN0ZCzWAyfrx0ztvIdIBSfBEUTNFXhX4bJVUx-pA-ljo2wGrZK0_GzBmGW6zIA9B7gcXgRGzwuh21wioR8JE7NicolrAU4wp1GZLLK8gQgKkpim2IYQejetBL',
#     'width': 1108}],
#   'place_id': 'ChIJYVh1UlBiHTEROvR1nROkemM',
#   'plus_code': {'compound_code': 'RM64+H6 Bangkok, Thailand',
#    'global_code': '7P52RM64+H6'},
#   'rating': 5,
#   'reference': 'ChIJYVh1UlBiHTEROvR1nROkemM',
#   'scope': 'GOOGLE',
#   'types': ['point_of_interest', 'establishment'],
#   'user_ratings_total': 1,
#   'vicinity': '106, 30-31 Soi Nawamin 70 Yake 3-2, Khwaeng Khlong Kum, Khet Bueng Kum'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 13.8182133, 'lng': 100.6551319},
#    'viewport': {'northeast': {'lat': 13.8195642802915,
#      'lng': 100.6564758802915},
#     'southwest': {'lat': 13.8168663197085, 'lng': 100.6537779197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/atm-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/atm_pinlet',
#   'name': 'ATM ธ.ไทยพาณิชย์ ศูนย์การค้า อิออน (ไทยแลนด์) สุขาภิบาล 1',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116221244012462640668">Paitoon Thongdee</a>'],
#     'photo_reference': 'AXCi2Q65ts2QICDBtPEapJ8MnFU6-J09DcHW37P33O69KGyt-vySPZhUaN91Y8eQeZ8H7FjBcWfBWVqcgi-fcXokTIHBjNAyL4Ld6d9vWZ5exgXyz8wWUPvY3elsFT6dbpSUkrcfgSK9q877y-i-VBVrVgkpD4tQXlNtYuGtAQhBaz4Q-yVU',
#     'width': 3024}],
#   'place_id': 'ChIJcWDSo1diHTEREDBBrtnGttU',
#   'plus_code': {'compound_code': 'RM94+73 Bangkok, Thailand',
#    'global_code': '7P52RM94+73'},
#   'rating': 5,
#   'reference': 'ChIJcWDSo1diHTEREDBBrtnGttU',
#   'scope': 'GOOGLE',
#   'types': ['atm', 'finance', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1,
#   'vicinity': 'เลขที่ 700 Thanon Nawamin, Khwaeng Khlong Kum, Khet Bueng Kum'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 13.8181287, 'lng': 100.6546664},
#    'viewport': {'northeast': {'lat': 13.8195349302915,
#      'lng': 100.6560429802915},
#     'southwest': {'lat': 13.8168369697085, 'lng': 100.6533450197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'หอแว่น Better Vision คลองกุ่ม',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1476,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102603104585226685367">หอแว่น Better Vision คลองกุ่ม</a>'],
#     'photo_reference': 'AXCi2Q5dMjPEM81bxs6ylZZYDVA1lPH2C-91JmpPiDdF6Yz6BmYnll4Ip-d2elTk10NwaHHfaRfbyvXSRuNwpS-It4udEqvluW0sPGCQJ2GOnfTuKfd5aToE-JoVMpl8GvT2KGhBLeBoYRmtsLrVpfQdm-StPyPn6jiffSNiV3_kbf69pOge',
#     'width': 1108}],
#   'place_id': 'ChIJZaI7A0RiHTERgPNeIEXeR_0',
#   'plus_code': {'compound_code': 'RM93+7V Bangkok, Thailand',
#    'global_code': '7P52RM93+7V'},
#   'rating': 5,
#   'reference': 'ChIJZaI7A0RiHTERgPNeIEXeR_0',
#   'scope': 'GOOGLE',
#   'types': ['point_of_interest', 'health', 'store', 'establishment'],
#   'user_ratings_total': 29,
#   'vicinity': '700, 11 ม.10 ถนน สุขาภิบาล 1, Khwaeng Khlong Kum, Khet Bueng Kum'},
#  {'geometry': {'location': {'lat': 13.8038424, 'lng': 100.6474732},
#    'viewport': {'northeast': {'lat': 13.84734307187288,
#      'lng': 100.6765840217291},
#     'southwest': {'lat': 13.77064566517742, 'lng': 100.6244264794941}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Bueng Kum',
#   'photos': [{'height': 1840,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117546977446891869801">vivat prateepchaikul</a>'],
#     'photo_reference': 'AXCi2Q5cFEHugLoKSjQBGuHluY5NLdtSz2aXIgHerED21XMmwIfQ_lJK9jRNCcSkRMc7LU3dD3h1eMYjo3A7aGID7dVDRVi8osTfHtFzxv5MtsREzNFz70C825O330iSBGl1cqdiavjP94w_Nx2B6vKhrk7vchkALEC2bd6IH2TpUUVFFAq8',
#     'width': 3264}],
#   'place_id': 'ChIJA6gszkRiHTERME_iXbIAAQM',
#   'reference': 'ChIJA6gszkRiHTERME_iXbIAAQM',
#   'scope': 'GOOGLE',
#   'types': ['sublocality_level_1', 'sublocality', 'political'],
#   'vicinity': 'Bueng Kum'}]
